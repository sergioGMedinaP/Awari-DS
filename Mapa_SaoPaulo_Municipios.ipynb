# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioGMedinaP/Awari-DS/blob/master/Mapa_SaoPaulo_Municipios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 16.5MB/s
# ...
#      |████████████████████████████████| 14.8MB 195kB/s
# ...
#      |████████████████████████████████| 6.5MB 40.0MB/s
# ...

# %%
import geopandas as gpd

# %%
sao_paulo = gpd.read_file("/content/drive/MyDrive/Awari-DS-09Mar2021/AWARI-DataScience/Dados_2021/Dados-IBGE/UF-SP-2020/SP_UF_2020/SP_UF_2020.shp")

# %%
sao_paulo
# Out:
#   CD_UF      NM_UF  ... NM_REGIAO                                           geometry
# 0    35  São Paulo  ...   Sudeste  MULTIPOLYGON (((-48.03716 -25.35794, -48.03750...
#
# [1 rows x 5 columns]

# %%
sao_paulo.plot()

# %%
sao_paulo.plot(figsize=(20,20))

# %%
sao_paulo_muni = gpd.read_file("/content/drive/MyDrive/Awari-DS-09Mar2021/AWARI-DataScience/Dados_2021/Dados-IBGE/UF-SP-2020/SP_Municipios_2020/SP_Municipios_2020.shp")

# %%
sao_paulo_muni
# Out:
#       CD_MUN  ...                                           geometry
# 0    3500105  ...  POLYGON ((-51.05425 -21.40465, -51.05300 -21.4...
# 1    3500204  ...  POLYGON ((-49.65795 -21.20333, -49.65645 -21.2...
# 2    3500303  ...  POLYGON ((-46.97640 -21.96818, -46.97599 -21.9...
# 3    3500402  ...  POLYGON ((-46.73501 -21.81891, -46.73431 -21.8...
# 4    3500501  ...  POLYGON ((-46.60614 -22.44173, -46.60347 -22.4...
# ..       ...  ...                                                ...
# 640  3557006  ...  POLYGON ((-47.37299 -23.52200, -47.37227 -23.5...
# 641  3557105  ...  POLYGON ((-50.02121 -20.33394, -50.02084 -20.3...
# 642  3557154  ...  POLYGON ((-49.99275 -21.03884, -49.99214 -21.0...
# 643  3557204  ...  POLYGON ((-49.68630 -22.93787, -49.68446 -22.9...
# 644  3557303  ...  POLYGON ((-46.93970 -22.18520, -46.93879 -22.1...
#
# [645 rows x 5 columns]

# %%
sao_paulo_muni.plot(figsize = (20,20))

# %%
sao_paulo_muni.plot(figsize = (30,30))
